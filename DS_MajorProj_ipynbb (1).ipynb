# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
from fbprophet import Prophet

# %%
#Importing the dataset
df=pd.read_excel('/content/drive/MyDrive/covid-data.xlsx')

# %%
df.nunique()
# Out:
# iso_code                                   219
# continent                                    6
# location                                   219
# date                                       490
# total_cases                              45506
# new_cases                                11706
# new_cases_smoothed                       22373
# total_deaths                             17356
# new_deaths                                2758
# new_deaths_smoothed                       6224
# total_cases_per_million                  64891
# new_cases_per_million                    37114
# new_cases_smoothed_per_million           41851
# total_deaths_per_million                 40247
# new_deaths_per_million                    7148
# new_deaths_smoothed_per_million           8481
# reproduction_rate                          366
# icu_patients                              2369
# icu_patients_per_million                  4965
# hosp_patients                             4607
# hosp_patients_per_million                 8199
# weekly_icu_admissions                      582
# weekly_icu_admissions_per_million          579
# weekly_hosp_admissions                    1178
# weekly_hosp_admissions_per_million        1172
# new_tests                                21281
# total_tests                              38018
# total_tests_per_thousand                 33454
# new_tests_per_thousand                    7006
# new_tests_smoothed                       23965
# new_tests_smoothed_per_thousand           7148
# positive_rate                              561
# tests_per_case                            5143
# tests_units                                  4
# total_vaccinations                        9264
# people_vaccinated                         8556
# people_fully_vaccinated                   6170
# new_vaccinations                          7280
# new_vaccinations_smoothed                10063
# total_vaccinations_per_hundred            3366
# people_vaccinated_per_hundred             2778
# people_fully_vaccinated_per_hundred       1602
# new_vaccinations_smoothed_per_million     5711
# stringency_index                           175
# population                                 217
# population_density                         200
# median_age                                 134
# aged_65_older                              184
# aged_70_older                              182
# gdp_per_capita                             190
# extreme_poverty                             75
# cardiovasc_death_rate                      188
# diabetes_prevalence                        141
# female_smokers                             110
# male_smokers                               125
# handwashing_facilities                      95
# hospital_beds_per_thousand                 100
# life_expectancy                            195
# human_development_index                    152
# dtype: int64

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85989 entries, 0 to 85988
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               85989 non-null  object
#  1   continent                              81842 non-null  object
#  2   location                               85989 non-null  object
#  3   date                                   85989 non-null  datetime64[ns]
#  4   total_cases                            83868 non-null  float64
#  5   new_cases                              83866 non-null  float64
#  6   new_cases_smoothed                     82865 non-null  float64
#  7   total_deaths                           74172 non-null  float64
#  8   new_deaths                             74330 non-null  float64
#  9   new_deaths_smoothed                    82865 non-null  float64
#  10  total_cases_per_million                83415 non-null  float64
#  11  new_cases_per_million                  83413 non-null  float64
#  12  new_cases_smoothed_per_million         82417 non-null  float64
#  13  total_deaths_per_million               73732 non-null  float64
#  14  new_deaths_per_million                 73890 non-null  float64
#  15  new_deaths_smoothed_per_million        82417 non-null  float64
#  16  reproduction_rate                      69488 non-null  float64
#  17  icu_patients                           8693 non-null   float64
#  18  icu_patients_per_million               8693 non-null   float64
#  19  hosp_patients                          10823 non-null  float64
#  20  hosp_patients_per_million              10823 non-null  float64
#  21  weekly_icu_admissions                  790 non-null    float64
#  22  weekly_icu_admissions_per_million      790 non-null    float64
#  23  weekly_hosp_admissions                 1298 non-null   float64
#  24  weekly_hosp_admissions_per_million     1298 non-null   float64
#  25  new_tests                              39265 non-null  float64
#  26  total_tests                            38970 non-null  float64
#  27  total_tests_per_thousand               38970 non-null  float64
#  28  new_tests_per_thousand                 39265 non-null  float64
#  29  new_tests_smoothed                     44987 non-null  float64
#  30  new_tests_smoothed_per_thousand        44987 non-null  float64
#  31  positive_rate                          43256 non-null  float64
#  32  tests_per_case                         42663 non-null  float64
#  33  tests_units                            46453 non-null  object
#  34  total_vaccinations                     9650 non-null   float64
#  35  people_vaccinated                      8991 non-null   float64
#  36  people_fully_vaccinated                6665 non-null   float64
#  37  new_vaccinations                       8183 non-null   float64
#  38  new_vaccinations_smoothed              15495 non-null  float64
#  39  total_vaccinations_per_hundred         9650 non-null   float64
#  40  people_vaccinated_per_hundred          8991 non-null   float64
#  41  people_fully_vaccinated_per_hundred    6665 non-null   float64
#  42  new_vaccinations_smoothed_per_million  15495 non-null  float64
#  43  stringency_index                       73311 non-null  float64
#  44  population                             85436 non-null  float64
#  45  population_density                     80044 non-null  float64
#  46  median_age                             77447 non-null  float64
#  47  aged_65_older                          76563 non-null  float64
#  48  aged_70_older                          77013 non-null  float64
#  49  gdp_per_capita                         77788 non-null  float64
#  50  extreme_poverty                        52949 non-null  float64
#  51  cardiovasc_death_rate                  78378 non-null  float64
#  52  diabetes_prevalence                    79540 non-null  float64
#  53  female_smokers                         61400 non-null  float64
#  54  male_smokers                           60495 non-null  float64
#  55  handwashing_facilities                 39387 non-null  float64
#  56  hospital_beds_per_thousand             71515 non-null  float64
#  57  life_expectancy                        81615 non-null  float64
#  58  human_development_index                78260 non-null  float64
# dtypes: datetime64[ns](1), float64(54), object(4)
# memory usage: 38.7+ MB

# %%
df.shape
# Out:
# (85989, 59)

# %%
#Preprocessing of the data
df=df.fillna(0)

# %%
df.head(12)
# Out:
#    iso_code continent  ... life_expectancy human_development_index
# 0       AFG      Asia  ...           64.83                   0.511
# 1       AFG      Asia  ...           64.83                   0.511
# 2       AFG      Asia  ...           64.83                   0.511
# 3       AFG      Asia  ...           64.83                   0.511
# 4       AFG      Asia  ...           64.83                   0.511
# 5       AFG      Asia  ...           64.83                   0.511
# 6       AFG      Asia  ...           64.83                   0.511
# 7       AFG      Asia  ...           64.83                   0.511
# 8       AFG      Asia  ...           64.83                   0.511
# 9       AFG      Asia  ...           64.83                   0.511
# 10      AFG      Asia  ...           64.83                   0.511
# 11      AFG      Asia  ...           64.83                   0.511
#
# [12 rows x 59 columns]

# %%
df.isnull().sum()
# Out:
# iso_code                                 0
# continent                                0
# location                                 0
# date                                     0
# total_cases                              0
# new_cases                                0
# new_cases_smoothed                       0
# total_deaths                             0
# new_deaths                               0
# new_deaths_smoothed                      0
# total_cases_per_million                  0
# new_cases_per_million                    0
# new_cases_smoothed_per_million           0
# total_deaths_per_million                 0
# new_deaths_per_million                   0
# new_deaths_smoothed_per_million          0
# reproduction_rate                        0
# icu_patients                             0
# icu_patients_per_million                 0
# hosp_patients                            0
# hosp_patients_per_million                0
# weekly_icu_admissions                    0
# weekly_icu_admissions_per_million        0
# weekly_hosp_admissions                   0
# weekly_hosp_admissions_per_million       0
# new_tests                                0
# total_tests                              0
# total_tests_per_thousand                 0
# new_tests_per_thousand                   0
# new_tests_smoothed                       0
# new_tests_smoothed_per_thousand          0
# positive_rate                            0
# tests_per_case                           0
# tests_units                              0
# total_vaccinations                       0
# people_vaccinated                        0
# people_fully_vaccinated                  0
# new_vaccinations                         0
# new_vaccinations_smoothed                0
# total_vaccinations_per_hundred           0
# people_vaccinated_per_hundred            0
# people_fully_vaccinated_per_hundred      0
# new_vaccinations_smoothed_per_million    0
# stringency_index                         0
# population                               0
# population_density                       0
# median_age                               0
# aged_65_older                            0
# aged_70_older                            0
# gdp_per_capita                           0
# extreme_poverty                          0
# cardiovasc_death_rate                    0
# diabetes_prevalence                      0
# female_smokers                           0
# male_smokers                             0
# handwashing_facilities                   0
# hospital_beds_per_thousand               0
# life_expectancy                          0
# human_development_index                  0
# dtype: int64

# %%
#Forecasting of data:
df=df.rename(columns={'date':'ds','new_cases':'y'})

# %%
df_cases=df[df['continent']=='Asia']

# %%
#Forecast for next 30 days of Asia Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases1=df[df['continent']=='Africa']

# %%
#Forecast for next 30 days of Africa Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.7)
model.fit(df_cases1)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases2=df[df['continent']=='Europe']

# %%
#Forecast for next 30 days of Europe Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases2)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases3=df[df['continent']=='Oceania']

# %%
#Forecast for next 30 days of Oceania Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases3)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases4=df[df['continent']=='North America']

# %%
#Forecast for next 30 days of North America Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.8)
model.fit(df_cases4)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases5=df[df['continent']=='South America']

# %%
#Forecast for next 30 days of South America Region
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases5)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases6=df[df['location']=='India']

# %%
#Forecast for next 30 days of India
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases6)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
df_cases7=df[df['location']=='United States']

# %%
#Forecast for next 30 days of United States
from fbprophet import Prophet
model=Prophet(changepoint_prior_scale=0.6)
model.fit(df_cases7)
forecast=model.make_future_dataframe(periods=30,freq='D')#periods is number of days and frequency is D=days,M=months
forecast=model.predict(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast,figsize=(20,5));

# %%
#Which country is having the lowest number of deaths?
df_min_deaths=df[['location','total_deaths']].sort_values('total_deaths')
df_min_deaths['location'][0:1]
# Out:
# 0    Afghanistan
# Name: location, dtype: object

# %%
#Which country is having the highest number of deaths?
df_max_deaths=df[['location','total_deaths']].sort_values('total_deaths')
df_max_deaths['location'].tail(1)
# Out:
# 84774    World
# Name: location, dtype: object

# %%
#Which country is having the lowest number of cases?
df_min_cases=df[['location','total_cases']].sort_values('total_cases')
df_min_cases['location'][0:1]
# Out:
# 9306    Bermuda
# Name: location, dtype: object

# %%
#Which country is having the highest number of cases?
df_max_cases=df[['location','total_cases']].sort_values('total_cases',ascending=False)
df_max_cases['location'][-1:]
# Out:
# 31322    Greenland
# Name: location, dtype: object
